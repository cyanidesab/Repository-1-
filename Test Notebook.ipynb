# %% [markdown]
# <h1> My Jupyter notebook on IBM watson studio

# %% [markdown]
# Sabareesh Venkatraman <br>
# Data Scientist </br>
# Global sourcing and procurement <br>
# </br>

# %% [markdown]
# My interest in data science owes to my curiosity for knowledge.<br>
# Specifically, I would like to pursue a career in Global sourcing and procurement.<br>
# I should be able to emulate Morgan Freeman in the movie Shawshank Redemption as a man who can get things.

# %% [markdown]
# <h3> My code in the next line will compute the value of 1+1

# %%
1+1
# Out:
# 2

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# 1. Text 1
# 2. Text 2
# 3. Text 3
# 4. Text 4
# 5. Text 5

# %% [markdown]
# - sorry
# - thank you
# - welcome

# %% [markdown]
#  - sorry
#   - thanks

# %% [markdown]
#  - sorry
#  - thanks

# %% [markdown]
# |sa| |avi| |S|
# |-| |-||-|
# |sa| |baree||s|

# %% [markdown]
# ~this is strike through~ and, this isn't
